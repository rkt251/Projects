# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("Media.csv")
df = df.dropna()
df = df.set_index('Date')
df.head()
# Out:
#            Disney   ATnT     BT    CBS   CCO  DISCA   GLOB    GOOGL   IMAX  \
# Date
# 11/7/2017  103.44  34.86  16.50  56.94  4.00  19.26  35.88  1052.39  24.55
# 11/6/2017  103.60  35.25  16.77  57.95  4.05  19.46  37.22  1042.68  25.40
# 11/3/2017  103.69  35.54  16.51  58.92  4.17  19.62  36.60  1049.99  26.05
# 11/2/2017  103.17  35.69  16.76  57.83  4.25  20.29  36.25  1042.97  26.40
# 11/1/2017  104.74  35.71  17.55  56.96  4.30  20.09  36.91  1042.60  25.00
#
#             MSFT    NFLX  PTSXQ   SBGI     VZ
# Date
# 11/7/2017  84.27  193.77   0.03  30.80  48.94
# 11/6/2017  84.47  196.02   0.03  30.10  48.99
# 11/3/2017  84.14  192.47   0.03  30.75  49.53
# 11/2/2017  84.05  194.16   0.03  30.20  49.21
# 11/1/2017  83.18  195.13   0.03  30.35  48.65

# %%
# summarize the data
df.describe()
# Out:
#            Disney        ATnT          BT         CBS         CCO       DISCA  \
# count  863.000000  863.000000  863.000000  863.000000  863.000000  863.000000
# mean   101.960463   36.939849   28.429154   56.495643    6.655898   29.364357
# std      8.177907    3.119070    6.151321    6.562746    2.099864    4.890513
# min     81.740000   31.800000   16.500000   38.670000    3.410000   19.060000
# 25%     95.405000   34.330000   22.680000   52.350000    4.950000   26.230000
# 50%    101.730000   36.320000   31.220000   56.440000    6.150000   28.130000
# 75%    108.215000   39.155000   33.465000   61.595000    7.800000   32.280000
# max    121.690000   43.470000   37.490000   69.510000   11.610000   44.830000
#
#              GLOB        GOOGL        IMAX        MSFT        NFLX  \
# count  863.000000   863.000000  863.000000  863.000000  863.000000
# mean    30.847416   732.653824   30.950649   55.164554  106.605886
# std     10.143960   144.796596    5.062779   10.284734   37.296029
# min     10.670000   497.100000   17.700000   40.290000   45.210000
# 25%     23.820000   583.700000   28.615000   46.625000   80.830000
# 50%     33.640000   744.270000   31.220000   52.970000   99.590000
# 75%     38.690000   823.945000   33.865000   62.970000  127.410000
# max     47.340000  1052.390000   43.220000   84.470000  202.680000
#
#             PTSXQ        SBGI          VZ
# count  863.000000  863.000000  863.000000
# mean     0.503418   30.724079   48.981112
# std      0.296392    3.580836    2.774324
# min      0.020000   23.940000   42.840000
# 25%      0.310000   28.350000   46.945000
# 50%      0.490000   30.250000   49.020000
# 75%      0.605000   32.630000   50.550000
# max      1.500000   42.900000   56.530000

# %%
df.shape
# Out:
# (863, 14)

# %%
# check the column names
df.columns
# Out:
# Index(['Disney', 'ATnT', 'BT', 'CBS', 'CCO', 'DISCA', 'GLOB', 'GOOGL', 'IMAX',
#        'MSFT', 'NFLX', 'PTSXQ', 'SBGI', 'VZ'],
#       dtype='object')

# %%
# Create  new data frame CDF AND VIZ from existing dataframe
# New dataframe contains selected columns from old dataframe
cdf=df[['Disney', 'ATnT', 'BT', 'CBS', 'CCO', 'DISCA', 'GLOB', 'GOOGL', 'IMAX',
       'MSFT', 'NFLX', 'PTSXQ', 'SBGI', 'VZ
# %%
msk = np.random.rand(len(df)) < 0.8
train = cdf[msk]
test = cdf[~msk]

# %%
plt.scatter(train.Disney,train.ATnT, color = 'blue')
plt.xlabel("Disney")
plt.ylabel("ATnT")
plt.show()

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
train_x = np.asanyarray(train[['ATnT']])
train_y = np.asanyarray(train[['Disney']])
regr.fit(train_x,train_y)

# The coefficients

print ('Coefficients : ',regr.coef_)
print ('Intercept : ',regr.intercept_)
print ('R-Square :', regr.score(train_x, train_y))
# Out:
# Coefficients :  [[-0.01231425]]
# Intercept :  [ 102.33166655]
# R-Square : 2.22731068317e-05

# %%
train_y_ = regr.predict(train_x)
plt.scatter(train.Disney,train.ATnT, color ='blue')
plt.plot(train_x, train_y_, color='black', linewidth =3)

# %%
test_x = np.asanyarray(test[['Disney']])
test_y = np.asanyarray(test[['ATnT']])
test_y_ = regr.predict(test_x)

print ("Residual Sum of Squares : %.2f"
      % np.mean((test_y_ - test_y)**2))

# Explained variance score : 1 is perfect prediction

print('Variance Score : %.2f' % regr.score(test_x,test_y))
# Out:
# Residual Sum of Squares : 4177.53
# Variance Score : -456.98

# %%
plt.scatter(test_x,test_y, color ='blue')
plt.plot(test_x, test_y_, color ='black', linewidth =3)
plt.xlabel("Disney")
plt.ylabel("ATnT")
plt.show()

# %%
#Non-Linear Model 
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

model = make_pipeline(PolynomialFeatures(2),Ridge())
model.fit(train_x,train_y)
train_y_ = model.predict(train_x)
plt.scatter(test_x,test_y, color = 'blue')
plt.scatter(train_x,train_y_,linewidth = 2)

# %%
#Multiple Linear Regression Model
from sklearn import linear_model
regr = linear_model.LinearRegression()
x = np.asanyarray(train[['ATnT', 'BT', 'CBS', 'CCO', 'DISCA', 'GLOB', 'GOOGL', 'IMAX',
       'MSFT', 'NFLX', 'PTSXQ', 'SBGI', 'VZ']])
y = np.asanyarray(train[['Disney']])
regr.fit (x, y)
predictions = model.predict(y)

#  The Coefficients

print ('Coefficients : ',regr.coef_)
print ('R-Square :', regr.score(x, y))
# Out:
# Coefficients :  [[  1.04552601e+00   6.57419316e-01   4.46885144e-01   4.39719618e-01
#    -7.84660035e-02  -7.86493389e-03  -3.53922079e-03   1.06650560e+00
#     2.18248516e-01   4.97941800e-02  -7.83596084e+00   2.12716389e-01
#    -1.42495471e+00]]
# R-Square : 0.784239733829

# %%
#Multiple Linear Regression Model
y_=regr.predict(test[['ATnT', 'BT', 'CBS', 'CCO', 'DISCA', 'GLOB', 'GOOGL', 'IMAX',
       'MSFT', 'NFLX', 'PTSXQ', 'SBGI', 'VZ']])
x = np.asanyarray(test[['ATnT', 'BT', 'CBS', 'CCO', 'DISCA', 'GLOB', 'GOOGL', 'IMAX',
       'MSFT', 'NFLX', 'PTSXQ', 'SBGI', 'VZ']])
y = np.asanyarray(test[['Disney']])
print("Residual Sum of Squares : %.2f"
     # %np.mean((y_ -y)**2))

#Explained Variance Score : 1 is perfect prediction

print('Variance Score : %.2f' % regr.score(x,y))
# Out:
# Residual Sum of Squares : 17.28
# Variance Score : 0.74

# %%
import statsmodels.api as sm
model = sm.OLS(y,x).fit()
predictions = model.predict(x)
model.summary()
# Out:
# C:\Users\rushi\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                     8181.
# Date:                Mon, 11 Dec 2017   Prob (F-statistic):          1.73e-218
# Time:                        18:33:52   Log-Likelihood:                -484.33
# No. Observations:                 173   AIC:                             994.7
# Df Residuals:                     160   BIC:                             1036.
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             1.1614      0.353      3.286      0.001       0.463       1.859
# x2             0.6029      0.132      4.569      0.000       0.342       0.863
# x3             0.2734      0.110      2.476      0.014       0.055       0.491
# x4             1.0238      0.333      3.072      0.002       0.366       1.682
# x5             0.2800      0.173      1.622      0.107      -0.061       0.621
# x6            -0.0733      0.088     -0.833      0.406      -0.247       0.100
# x7             0.0229      0.013      1.775      0.078      -0.003       0.048
# x8             1.2566      0.093     13.479      0.000       1.073       1.441
# x9             0.1978      0.138      1.433      0.154      -0.075       0.470
# x10            0.0857      0.032      2.684      0.008       0.023       0.149
# x11           -4.4016      2.561     -1.718      0.088      -9.460       0.657
# x12           -0.0422      0.170     -0.248      0.804      -0.378       0.294
# x13           -1.1889      0.257     -4.633      0.000      -1.696      -0.682
# ==============================================================================
# Omnibus:                        0.303   Durbin-Watson:                   0.695
# Prob(Omnibus):                  0.859   Jarque-Bera (JB):                0.434
# Skew:                          -0.083   Prob(JB):                        0.805
# Kurtosis:                       2.818   Cond. No.                     6.22e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.22e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#
# x6          6.384e-16   1.33e-15      0.478      0.633   -1.98e-15    3.26e-15
# x7         -2.089e-15    8.3e-16     -2.518      0.012   -3.72e-15    -4.6e-16
# x8         -1.943e-15   1.48e-15     -1.313      0.190   -4.85e-15    9.63e-16
# x9          9.714e-16   1.08e-15      0.903      0.367   -1.14e-15    3.08e-15
# x10        -2.637e-16   2.86e-16     -0.922      0.357   -8.25e-16    2.98e-16
# x11         1.471e-15   2.76e-15      0.532      0.595   -3.95e-15     6.9e-15
# ==============================================================================
# Omnibus:                        3.015   Durbin-Watson:                   0.011
# Prob(Omnibus):                  0.221   Jarque-Bera (JB):                3.092
# Skew:                          -0.152   Prob(JB):                        0.213
# Kurtosis:                       2.877   Cond. No.                         254.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Multiple Linear Regression Model 5
from sklearn import linear_model
regr = linear_model.LinearRegression()
x = np.asanyarray(train[['Disney', 'ATnT', 'BT', 'CBS', 'CCO', 'DISCA', 'GLOB', 'IMAX',
       'MSFT', 'NFLX']])
y = np.asanyarray(train[['Disney']])
regr.fit (x, y)


#  The Coefficients

print ('Intercept : ',regr.intercept_)
print ('Coefficients : ',regr.coef_)
print ('R-Square :', regr.score(x, y))
# Out:
# Intercept :  [  2.13162821e-13]
# Coefficients :  [[  1.00000000e+00  -3.80178761e-16   6.24692557e-16   1.05593918e-18
#     2.82613015e-16   2.23750735e-17  -8.95775323e-17   2.38065163e-16
#    -7.02672531e-16  -2.03191095e-15]]
# R-Square : 1.0

# %%
import statsmodels.api as sm
model = sm.OLS(y,x).fit()
predictions = model.predict(x)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.266e+31
# Date:                Mon, 11 Dec 2017   Prob (F-statistic):               0.00
# Time:                        18:33:52   Log-Likelihood:                 19080.
# No. Observations:                 690   AIC:                        -3.814e+04
# Df Residuals:                     680   BIC:                        -3.809e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             1.0000   2.01e-15   4.97e+14      0.000       1.000       1.000
# x2          1.665e-16   4.62e-15      0.036      0.971   -8.91e-15    9.24e-15
# x3         -1.874e-15   2.96e-15     -0.633      0.527   -7.68e-15    3.94e-15
# x4         -1.527e-15   2.85e-15     -0.535      0.593   -7.13e-15    4.08e-15
# x5         -9.159e-16   8.23e-15     -0.111      0.911   -1.71e-14    1.52e-14
# x6          8.188e-16    3.5e-15      0.234      0.815   -6.05e-15    7.69e-15
# x7         -1.443e-15   2.09e-15     -0.689      0.491   -5.55e-15    2.67e-15
# x8         -1.749e-15    3.7e-15     -0.472      0.637   -9.02e-15    5.52e-15
# x9          6.106e-16   2.63e-15      0.232      0.817   -4.56e-15    5.78e-15
# x10         -1.11e-15    7.6e-16     -1.461      0.145    -2.6e-15    3.82e-16
# ==============================================================================
# Omnibus:                       31.460   Durbin-Watson:                   0.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               31.924
# Skew:                          -0.491   Prob(JB):                     1.17e-07
# Kurtosis:                       2.617   Cond. No.                         175.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Multiple Linear Regression Model 5
from sklearn import linear_model
regr = linear_model.LinearRegression()
x = np.asanyarray(train[['BT', 'CBS', 'DISCA', 'GLOB', 'NFLX']])
y = np.asanyarray(train[['Disney']])
regr.fit (x, y)


#  The Coefficients

print ('Intercept : ',regr.intercept_)
print ('Coefficients : ',regr.coef_)
print ('R-Square :', regr.score(x, y))
# Out:
# Intercept :  [ 15.85638063]
# Coefficients :  [[ 1.25515635  0.81692596 -0.41131596  0.15717254  0.10705817]]
# R-Square : 0.432991750341

# %%
import statsmodels.api as sm
model = sm.OLS(y,x).fit()
predictions = model.predict(x)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                 3.710e+04
# Date:                Mon, 11 Dec 2017   Prob (F-statistic):               0.00
# Time:                        18:36:14   Log-Likelihood:                -2237.9
# No. Observations:                 690   AIC:                             4486.
# Df Residuals:                     685   BIC:                             4509.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             1.4041      0.051     27.412      0.000       1.304       1.505
# x2             0.9085      0.045     20.156      0.000       0.820       0.997
# x3            -0.3040      0.086     -3.518      0.000      -0.474      -0.134
# x4             0.2232      0.039      5.749      0.000       0.147       0.299
# x5             0.1186      0.012     10.134      0.000       0.096       0.142
# ==============================================================================
# Omnibus:                       15.075   Durbin-Watson:                   0.086
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.573
# Skew:                           0.338   Prob(JB):                     0.000415
# Kurtosis:                       3.289   Cond. No.                         59.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
