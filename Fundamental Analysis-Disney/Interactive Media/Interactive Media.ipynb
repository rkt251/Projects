# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("Interactive_media.csv")
df = df.dropna()
df = df.set_index('Date')
df.head()
# Out:
#             Disney     AMZN     KO      EA     FL     HSY      K    NKE   NOK  \
# Date
# 10/24/2017  103.44  1123.17  46.18  111.70  29.24  109.36  61.20  55.15  5.05
# 10/23/2017  103.60  1120.66  46.32  112.46  29.65  109.12  61.48  56.04  5.09
# 10/20/2017  103.69  1111.60  46.38  113.20  29.85  109.02  61.45  55.71  4.97
# 10/19/2017  103.17  1094.22  46.59  112.69  30.01  109.35  61.70  55.12  5.03
# 10/18/2017  104.74  1103.68  46.40  114.47  29.91  110.05  61.79  55.07  4.94
#
#                 PM    PHG   SBUX    TGT    TSN    NVDA   INTC    AMD
# Date
# 10/24/2017  108.57  40.88  57.22  57.89  71.16  216.14  45.58  11.26
# 10/23/2017  109.36  41.15  56.57  59.29  71.52  205.32  46.30  11.12
# 10/20/2017  109.52  41.46  56.03  59.36  71.54  209.16  46.70  11.71
# 10/19/2017  108.15  41.12  54.87  59.79  71.41  212.03  46.78  12.05
# 10/18/2017  112.51  41.24  55.13  58.86  71.55  209.63  46.70  11.93

# %%
# summarize the data
df.describe()
# Out:
#             Disney         AMZN           KO           EA           FL  \
# count  2023.000000  2023.000000  2023.000000  2023.000000  2023.000000
# mean     72.304938   405.449432    38.417435    42.815576    42.115022
# std      28.839394   258.715930     5.255288    30.583138    19.134721
# min      29.000000   108.610000    25.020000    10.950000    11.290000
# 25%      42.355000   209.725000    34.515000    17.655000    25.095000
# 50%      73.220000   308.010000    39.940000    26.530000    36.410000
# 75%      99.150000   569.620000    42.140000    67.520000    59.740000
# max     121.690000  1123.170000    46.890000   121.970000    79.200000
#
#                HSY            K          NKE          NOK           PM  \
# count  2023.000000  2023.000000  2023.000000  2023.000000  2023.000000
# mean     81.627197    61.832170    37.996525     6.613515    83.297331
# std      21.599297     8.955384    15.130079     2.476691    17.003985
# min      36.180000    46.510000    15.330000     1.690000    43.170000
# 25%      60.135000    53.440000    23.625000     5.100000    75.885000
# 50%      90.320000    62.190000    37.000000     6.370000    85.600000
# 75%      97.640000    67.815000    52.805000     7.890000    91.325000
# max     115.960000    86.980000    67.170000    15.650000   122.900000
#
#                PHG         SBUX          TGT          TSN         NVDA  \
# count  2023.000000  2023.000000  2023.000000  2023.000000  2023.000000
# mean     28.689525    36.914844    62.876629    35.942679    35.394123
# std       5.008791    16.318909     9.717550    18.745764    42.116910
# min      16.870000    10.850000    46.330000    12.240000     8.880000
# 25%      25.900000    22.865000    54.630000    18.740000    14.255000
# 50%      29.120000    36.930000    61.250000    33.170000    18.190000
# 75%      31.675000    54.615000    70.220000    46.280000    28.670000
# max      42.100000    64.570000    85.010000    76.760000   216.140000
#
#               INTC          AMD
# count  2023.000000  2023.000000
# mean     27.860860     5.769214
# std       6.043892     3.317239
# min      17.670000     1.620000
# 25%      22.300000     2.850000
# 50%      26.540000     4.530000
# 75%      33.900000     7.785000
# max      47.100000    15.200000

# %%
df.shape
# Out:
# (2023, 17)

# %%
# check the column names
df.columns
# Out:
# Index(['Disney', 'AMZN', 'KO', 'EA', 'FL', 'HSY', 'K', 'NKE', 'NOK', 'PM',
>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A41F3EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A420FBA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A42BDCF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A431F5C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A4389B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A43E8F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A4462978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A44CB400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A450C0F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A4570940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A4479198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A4633940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A46940F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A46FF780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A475EAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A47D8588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A4838EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A487ABE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A49026A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A4917400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A49D14E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A4A28D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A4A9B320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A4AF9780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A4B74160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A4BD2BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A4C17898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A4C9D358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A4CB2240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A4D6A198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A4DC2A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A4E2EF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A4E94438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A4F07DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A4F6D860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A4FB1550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A5030FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A504C828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A50FDE10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A515F6D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A51C8C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A522F0F0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A52A1A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A5309518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A534A208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A53CDC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A53E3550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A5498AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A54F8390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A5564908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A55C3D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A563D748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A56A61D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A56DFE80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A5742160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A4738CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A5807160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A585F8D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A58C8F60>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A59312E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A6973D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A69D9710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A6A1D400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A6A9EE80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A6AB99E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A6B6ACC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A6BCA588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A6C35B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A6C94F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A6D0D940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A6D753C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A6DB70B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A6E39B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A6E4DCF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A6F04978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A6F65240>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A6FCE7B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A702EC18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A70A85F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A7111080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A714CD30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A71D27F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A71E95C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A729F630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A72FAEB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A736D470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A73C98D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A74442B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A74A4CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A74E69E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A756C4A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A75837F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A76392E8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A7692B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A7704128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A7763588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A77D7F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A783F9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A78816A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A790A160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A791FFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A79CDF60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A7A2F828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A7A97DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A7B01240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A7B74BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A7BDA668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A7C1A358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A7C9BDD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A7BFA7B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A7D3B160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A7465518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A7DF8978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A7E59CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A7ED1780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A7F3A128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A7F75DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A7FFF898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A8011828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A80C96D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A8121F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A8193518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A81F4978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A826D358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A82CCDA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A8310A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A8397550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A83AC320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A8463390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A84BEC18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A85321D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A858F630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A8600FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A8666A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A86AB748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A8732208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A8746978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A87FF048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A88588D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A88C4E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A89292E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A899BC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A8A03710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4A8A46400>]], dtype=object)

# %%
msk = np.random.rand(len(df)) < 0.8
train = cdf[msk]
test = cdf[~msk]

# %%
plt.scatter(train.Disney,train.AMZN, color = 'blue')
plt.xlabel("Disney")
plt.ylabel("AMZN")
plt.show()

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
train_x = np.asanyarray(train[['AMZN']])
train_y = np.asanyarray(train[['Disney']])
regr.fit(train_x,train_y)

# The coefficients

print ('Coefficients : ',regr.coef_)
print ('Intercept : ',regr.intercept_)
print ('R-Square :', regr.score(train_x, train_y))
# Out:
# Coefficients :  [[ 0.08976338]]
# Intercept :  [ 35.7959512]
# R-Square : 0.647445381764

# %%
train_y_ = regr.predict(train_x)
plt.scatter(train.Disney,train.AMZN, color ='blue')
plt.plot(train_x, train_y_, color='black', linewidth =3)

# %%
test_x = np.asanyarray(test[['Disney']])
test_y = np.asanyarray(test[['AMZN']])
test_y_ = regr.predict(test_x)

print ("Residual Sum of Squares : %.2f"
      % np.mean((test_y_ - test_y)**2))

# Explained variance score : 1 is perfect prediction

print('Variance Score : %.2f' % regr.score(test_x,test_y))
# Out:
# Residual Sum of Squares : 199652.69
# Variance Score : -2.03

# %%
plt.scatter(test_x,test_y, color ='blue')
plt.plot(test_x, test_y_, color ='black', linewidth =3)
plt.xlabel("Disney")
plt.ylabel("AMZN")
plt.show()

# %%
#Non-Linear Model 
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

model = make_pipeline(PolynomialFeatures(2),Ridge())
model.fit(train_x,train_y)
train_y_ = model.predict(train_x)
plt.scatter(test_x,test_y, color = 'blue')
plt.scatter(train_x,train_y_,linewidth = 2)

# %%
#Multiple Linear Regression Model
from sklearn import linear_model
regr = linear_model.LinearRegression()
x = np.asanyarray(train[['AMZN', 'KO', 'EA', 'FL', 'HSY', 'K', 'NKE', 'NOK', 'PM',
       'PHG', 'SBUX', 'TGT', 'TSN', 'NVDA', 'INTC', 'AMD']])
y = np.asanyarray(train[['Disney']])
regr.fit (x, y)
predictions = model.predict(y)

#  The Coefficients

print ('Coefficients : ',regr.coef_)
print ('R-Square :', regr.score(x, y))
# Out:
# Coefficients :  [[-0.01961031  0.92384761  0.35432091  0.55237853  0.28318885 -0.36178221
#    0.35154118  0.21716941 -0.20526335  0.71838998  0.30226576  0.09594903
#   -0.14209636 -0.04931197  0.2221309   0.22747204]]
# R-Square : 0.980276734511

# %%
#Multiple Linear Regression Model
y_=regr.predict(test[['AMZN', 'KO', 'EA', 'FL', 'HSY', 'K', 'NKE', 'NOK', 'PM',
       'PHG', 'SBUX', 'TGT', 'TSN', 'NVDA', 'INTC', 'AMD']])
x = np.asanyarray(test[['AMZN', 'KO', 'EA', 'FL', 'HSY', 'K', 'NKE', 'NOK', 'PM',
       'PHG', 'SBUX', 'TGT', 'TSN', 'NVDA', 'INTC', 'AMD']])
y = np.asanyarray(test[['Disney']])
print("Residual Sum of Squares : %.2f"
     # %np.mean((y_ -y)**2))

#Explained Variance Score : 1 is perfect prediction

print('Variance Score : %.2f' % regr.score(x,y))
# Out:
# Residual Sum of Squares : 17.82
# Variance Score : 0.98

# %%
import statsmodels.api as sm
model = sm.OLS(y,x).fit()
predictions = model.predict(x)
model.summary()
# Out:
# C:\Users\rushi\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                     7915.
# Date:                Mon, 11 Dec 2017   Prob (F-statistic):               0.00
# Time:                        18:24:44   Log-Likelihood:                -1138.9
# No. Observations:                 396   AIC:                             2310.
# Df Residuals:                     380   BIC:                             2374.
# Df Model:                          16
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0270      0.007     -4.145      0.000      -0.040      -0.014
# x2             0.6048      0.192      3.146      0.002       0.227       0.983
# x3             0.2971      0.048      6.222      0.000       0.203       0.391
# x4             0.5353      0.042     12.769      0.000       0.453       0.618
# x5             0.3414      0.037      9.176      0.000       0.268       0.415
# x6            -0.4917      0.086     -5.718      0.000      -0.661      -0.323
# x7             0.1135      0.114      0.999      0.318      -0.110       0.337
# x8             0.3537      0.232      1.524      0.128      -0.103       0.810
# x9            -0.2549      0.059     -4.320      0.000      -0.371      -0.139
# x10            0.4513      0.103      4.362      0.000       0.248       0.655
# x11            0.6918      0.112      6.191      0.000       0.472       0.911
# x12           -0.0026      0.046     -0.056      0.956      -0.093       0.088
# x13           -0.0184      0.054     -0.343      0.732      -0.124       0.087
# x14            0.0187      0.034      0.545      0.586      -0.049       0.086
# x15            0.1516      0.108      1.399      0.163      -0.062       0.365
# x16           -0.1136      0.190     -0.598      0.551      -0.487       0.260
# ==============================================================================
# Omnibus:                        6.932   Durbin-Watson:                   0.502
# Prob(Omnibus):                  0.031   Jarque-Bera (JB):               10.437
# Skew:                           0.048   Prob(JB):                      0.00542
# Kurtosis:                       3.790   Cond. No.                         616.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Multiple Linear Regression Model
from sklearn import linear_model
regr = linear_model.LinearRegression()
x = np.asanyarray(train[['AMZN', 'KO', 'EA', 'FL', 'HSY', 'K', 'NKE', 'PM',
       'PHG', 'SBUX', 'AMD']])
y = np.asanyarray(train[['Disney']])
regr.fit (x, y)


#  The Coefficients

print ('Intercept : ',regr.intercept_)
print ('Coefficients : ',regr.coef_)
print ('R-Square :', regr.score(x, y))
# Out:
# Intercept :  [-18.2753888]
# Coefficients :  [[-0.03436597  1.00241202  0.34092359  0.58539668  0.25811785 -0.42138344
#    0.41759459 -0.23748068  0.7404194   0.37174678  0.12688455]]
# R-Square : 0.979511603272

# %%
import statsmodels.api as sm
model = sm.OLS(y,x).fit()
predictions = model.predict(x)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                 4.962e+04
# Date:                Mon, 11 Dec 2017   Prob (F-statistic):               0.00
# Time:                        18:28:33   Log-Likelihood:                -4651.4
# No. Observations:                1627   AIC:                             9325.
# Df Residuals:                    1616   BIC:                             9384.
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0274      0.002    -12.503      0.000      -0.032      -0.023
# x2             0.5875      0.075      7.880      0.000       0.441       0.734
# x3             0.3476      0.016     21.841      0.000       0.316       0.379
# x4             0.5703      0.017     32.810      0.000       0.536       0.604
# x5             0.3347      0.015     22.184      0.000       0.305       0.364
# x6            -0.5077      0.026    -19.559      0.000      -0.559      -0.457
# x7             0.4143      0.046      9.058      0.000       0.325       0.504
# x8            -0.2352      0.024     -9.677      0.000      -0.283      -0.187
# x9             0.6137      0.029     20.950      0.000       0.556       0.671
# x10            0.3521      0.051      6.900      0.000       0.252       0.452
# x11           -0.1202      0.060     -2.003      0.045      -0.238      -0.003
# ==============================================================================
# Omnibus:                       33.133   Durbin-Watson:                   0.128
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               64.830
# Skew:                          -0.075   Prob(JB):                     8.36e-15
# Kurtosis:                       3.966   Cond. No.                         398.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
